# %% [markdown]
# # Creating August Schedule

# %%
## Setup and Imports
import sys
from pathlib import Path
import os
import pandas as pd
from datetime import date, timedelta

# %%
# Add project root (one level up from 'notebooks') to sys.path
project_root = Path.cwd().parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

# %%
# Import our scheduling engine
from engine.engine import create_im_schedule

# %% [markdown]
# ## IM Schedule

# %%
# Run the scheduler from August 4-29
schedule_df, provider_summary_df, solution_status = create_im_schedule(
    config_path = '../config/internal_medicine.yml',
    leave_requests_path = '../data/leave_requests.csv',
    inpatient_path = '../data/inpatient.csv',
    start_date = date(2025, 8, 4),
    end_date = date(2025, 8, 29),
    min_staffing_search = True,
    initial_min_providers = 4,
    random_seed = 42
)
# Out:
# 2025-05-14 22:50:40,207 - engine.engine - INFO - Creating schedule for Internal Medicine from 2025-08-04 to 2025-08-29
# 2025-05-14 22:50:40,220 - engine.engine - INFO - Parsing input files
# 2025-05-14 22:50:40,227 - engine.engine - INFO - Building calendar
# 2025-05-14 22:50:40,228 - engine.engine - INFO - Beginning iterative min_providers search, starting with 4
# 2025-05-14 22:50:40,228 - engine.engine - INFO - Attempting to solve with min_providers_per_session = 4
# 2025-05-14 22:50:40,242 - engine.engine - WARNING - No feasible solution found with min_providers = 4
# 2025-05-14 22:50:40,242 - engine.engine - INFO - Attempting to solve with min_providers_per_session = 3
# 2025-05-14 22:50:40,261 - engine.engine - WARNING - No feasible solution found with min_providers = 3
# 2025-05-14 22:50:40,261 - engine.engine - INFO - Attempting to solve with min_providers_per_session = 2
# 2025-05-14 22:50:40,278 - engine.engine - INFO - Found optimal solution with min_providers = 2
# 2025-05-14 22:50:40,279 - engine.engine - INFO - Successfully found solution with highest possible min_providers = 2

# %%
schedule_df
# Out:
#           date day_of_week    session                            providers  \
# 0   2025-08-04      Monday    morning                          Mcrae,Miles
# 1   2025-08-04      Monday  afternoon                          Mcrae,Miles
# 2   2025-08-05     Tuesday    morning      Mcrae,Miles,Selig,Stewart,Tanay
# 3   2025-08-05     Tuesday  afternoon            Mcrae,Selig,Stewart,Tanay
# 4   2025-08-06   Wednesday    morning                  Selig,Stewart,Tanay
# 5   2025-08-06   Wednesday  afternoon                          Selig,Tanay
# 6   2025-08-07    Thursday  afternoon                    Mcrae,Selig,Tanay
# 7   2025-08-08      Friday    morning                        Stewart,Tanay
# 8   2025-08-08      Friday  afternoon                          Mcrae,Selig
# 9   2025-08-11      Monday    morning                          Miles,Selig
# 10  2025-08-11      Monday  afternoon                          Miles,Selig
# 11  2025-08-12     Tuesday    morning           Miles,Stewart,Tanay,Wadlin
# 12  2025-08-12     Tuesday  afternoon       Bornstein,Stewart,Tanay,Wadlin
# 13  2025-08-13   Wednesday    morning     Mcrae,Selig,Stewart,Tanay,Wadlin
# 14  2025-08-13   Wednesday  afternoon             Mcrae,Selig,Tanay,Wadlin
# 15  2025-08-14    Thursday  afternoon          Bornstein,Mcrae,Selig,Tanay
# 16  2025-08-15      Friday    morning           Mcrae,Stewart,Tanay,Wadlin
# 17  2025-08-15      Friday  afternoon                          Mcrae,Selig
# 18  2025-08-18      Monday    morning                          Mcrae,Selig
# 19  2025-08-18      Monday  afternoon                          Mcrae,Selig
# 20  2025-08-19     Tuesday    morning              Bornstein,Stewart,Tanay
# 21  2025-08-19     Tuesday  afternoon              Bornstein,Stewart,Tanay
# 22  2025-08-20   Wednesday    morning  Bornstein,Mcrae,Selig,Stewart,Tanay
# 23  2025-08-20   Wednesday  afternoon                    Mcrae,Selig,Tanay
# 24  2025-08-21    Thursday  afternoon                          Selig,Tanay
# 25  2025-08-22      Friday    morning            Mcrae,Selig,Stewart,Tanay
# 26  2025-08-22      Friday  afternoon                      Bornstein,Mcrae
# 27  2025-08-25      Monday    morning                      Bornstein,Mcrae
# 28  2025-08-25      Monday  afternoon                      Bornstein,Mcrae
# 29  2025-08-26     Tuesday    morning           Selig,Stewart,Tanay,Wadlin
# 30  2025-08-26     Tuesday  afternoon           Selig,Stewart,Tanay,Wadlin
# 31  2025-08-27   Wednesday    morning     Mcrae,Selig,Stewart,Tanay,Wadlin
# 32  2025-08-27   Wednesday  afternoon          Bornstein,Mcrae,Selig,Tanay
# 33  2025-08-28    Thursday  afternoon                    Mcrae,Selig,Tanay
# 34  2025-08-29      Friday    morning                  Selig,Stewart,Tanay
# 35  2025-08-29      Friday  afternoon                      Bornstein,Mcrae
#
#     count
# 0       2
# 1       2
# 2       5
# 3       4
# 4       3
# 5       2
# 6       3
# 7       2
# 8       2
# 9       2
# 10      2
# 11      4
# 12      4
# 13      5
# 14      4
# 15      4
# 16      4
# 17      2
# 18      2
# 19      2
# 20      3
# 21      3
# 22      5
# 23      3
# 24      2
# 25      4
# 26      2
# 27      2
# 28      2
# 29      4
# 30      4
# 31      5
# 32      4
# 33      3
# 34      3
# 35      2

# %%
provider_summary_df
# Out:
#     provider  week_32  week_33  week_34  week_35  total_sessions
# 0  Bornstein        0        2        4        4              10
# 1      Mcrae        6        5        6        6              23
# 2      Miles        3        3        0        0               6
# 3     Orcutt        0        0        0        0               0
# 4      Selig        6        6        6        6              24
# 5    Stewart        4        4        4        4              16
# 6      Tanay        6        6        6        6              24
# 7     Wadlin        0        5        0        3               8

# %%
solution_status
# Out:
# {'Status': 'OPTIMAL',
#  'Minimum providers per session': 2,
#  'Objective value': 4100.0,
#  'Solve time': '0.019750 seconds',
#  'Branches': 640,
#  'Conflicts': 0}

# %% [markdown]
# ## Peds Schedule

# %%
# Import our scheduling engine
from engine.engine import create_peds_schedule

# %%
# Run the scheduler from August 4-29
schedule_df, provider_summary_df, call_summary_df, solution_status = create_peds_schedule(
    config_path = '../config/pediatric.yml',
    leave_requests_path = '../data/leave_requests.csv',
    inpatient_path = '../data/inpatient.csv',
    start_date = date(2025, 8, 3),
    end_date = date(2025, 8, 29),
    min_staffing_search = True,
    initial_min_providers = 4,
    random_seed = 42
)
# Out:
# 2025-05-14 22:50:40,299 - engine.engine - INFO - Creating schedule for Pediatric from 2025-08-03 to 2025-08-29
# 2025-05-14 22:50:40,300 - engine.engine - INFO - Parsing input files
# 2025-05-14 22:50:40,307 - engine.engine - INFO - Building calendar
# 2025-05-14 22:50:40,308 - engine.engine - INFO - Beginning iterative min_providers search, starting with 4
# 2025-05-14 22:50:40,308 - engine.engine - INFO - Attempting to solve with min_providers_per_session = 4
# 2025-05-14 22:50:40,329 - engine.engine - WARNING - No feasible solution found with min_providers = 4
# 2025-05-14 22:50:40,330 - engine.engine - INFO - Attempting to solve with min_providers_per_session = 3
# 2025-05-14 22:50:40,350 - engine.engine - WARNING - No feasible solution found with min_providers = 3
# 2025-05-14 22:50:40,351 - engine.engine - INFO - Attempting to solve with min_providers_per_session = 2
# 2025-05-14 22:50:40,370 - engine.engine - WARNING - No feasible solution found with min_providers = 2
# 2025-05-14 22:50:40,370 - engine.engine - INFO - Attempting to solve with min_providers_per_session = 1
# 2025-05-14 22:50:40,403 - engine.engine - INFO - Found optimal solution with min_providers = 1
# 2025-05-14 22:50:40,405 - engine.engine - INFO - Successfully found solution with highest possible min_providers = 1

# %%
schedule_df
# Out:
#           date day_of_week   sessions                          providers  \
# 0   2025-08-03      Sunday       call                            Bedelle
# 1   2025-08-04      Monday    morning                   Bedelle,Carrasco
# 2   2025-08-04      Monday  afternoon                           Carrasco
# 3   2025-08-04      Monday       call                           Carrasco
# 4   2025-08-05     Tuesday    morning                   Bedelle,Carrasco
# 5   2025-08-05     Tuesday  afternoon                            Bedelle
# 6   2025-08-05     Tuesday       call                             Powell
# 7   2025-08-06   Wednesday    morning            Carrasco,Miller,Sridhar
# 8   2025-08-06   Wednesday  afternoon            Carrasco,Miller,Sridhar
# 9   2025-08-06   Wednesday       call                            Sridhar
# 10  2025-08-07    Thursday  afternoon            Bedelle,Carrasco,Miller
# 11  2025-08-07    Thursday       call                             Miller
# 12  2025-08-08      Friday    morning                     Bedelle,Miller
# 13  2025-08-08      Friday  afternoon                            Bedelle
# 14  2025-08-10      Sunday       call                            Sridhar
# 15  2025-08-11      Monday    morning             Bedelle,Miller,Sridhar
# 16  2025-08-11      Monday  afternoon            Bedelle,Menachof,Miller
# 17  2025-08-11      Monday       call                           Menachof
# 18  2025-08-12     Tuesday    morning     Bedelle,Mador,Menachof,Sridhar
# 19  2025-08-12     Tuesday  afternoon              Bedelle,Mador,Sridhar
# 20  2025-08-12     Tuesday       call                            Bedelle
# 21  2025-08-13   Wednesday    morning     Bedelle,Mador,Menachof,Sridhar
# 22  2025-08-13   Wednesday  afternoon                      Mador,Sridhar
# 23  2025-08-13   Wednesday       call                              Mador
# 24  2025-08-14    Thursday  afternoon             Bedelle,Miller,Sridhar
# 25  2025-08-14    Thursday       call                             Powell
# 26  2025-08-15      Friday    morning                             Miller
# 27  2025-08-15      Friday  afternoon                             Miller
# 28  2025-08-17      Sunday       call                            Sridhar
# 29  2025-08-18      Monday    morning                     Miller,Sridhar
# 30  2025-08-18      Monday  afternoon                             Miller
# 31  2025-08-18      Monday       call                             Miller
# 32  2025-08-19     Tuesday    morning    Bedelle,Carrasco,Miller,Sridhar
# 33  2025-08-19     Tuesday  afternoon           Bedelle,Carrasco,Sridhar
# 34  2025-08-19     Tuesday       call                               Shin
# 35  2025-08-20   Wednesday    morning    Bedelle,Carrasco,Miller,Sridhar
# 36  2025-08-20   Wednesday  afternoon    Bedelle,Carrasco,Miller,Sridhar
# 37  2025-08-20   Wednesday       call                           Carrasco
# 38  2025-08-21    Thursday  afternoon                     Miller,Sridhar
# 39  2025-08-21    Thursday       call                             Powell
# 40  2025-08-22      Friday    morning                            Bedelle
# 41  2025-08-22      Friday  afternoon                            Bedelle
# 42  2025-08-24      Sunday       call                               Shin
# 43  2025-08-25      Monday    morning           Bedelle,Carrasco,Sridhar
# 44  2025-08-25      Monday  afternoon           Bedelle,Carrasco,Sridhar
# 45  2025-08-25      Monday       call                           Carrasco
# 46  2025-08-26     Tuesday    morning  Bedelle,Carrasco,Menachof,Sridhar
# 47  2025-08-26     Tuesday  afternoon                    Bedelle,Sridhar
# 48  2025-08-26     Tuesday       call                           Menachof
# 49  2025-08-27   Wednesday    morning                   Bedelle,Carrasco
# 50  2025-08-27   Wednesday  afternoon                   Bedelle,Carrasco
# 51  2025-08-27   Wednesday       call                            Bedelle
# 52  2025-08-28    Thursday  afternoon                           Carrasco
# 53  2025-08-28    Thursday       call                             Powell
# 54  2025-08-29      Friday    morning                               Shin
# 55  2025-08-29      Friday  afternoon                               Shin
#
#     count
# 0     NaN
# 1     2.0
# 2     1.0
# 3     NaN
# 4     2.0
# 5     1.0
# 6     NaN
# 7     3.0
# 8     3.0
# 9     NaN
# 10    3.0
# 11    NaN
# 12    2.0
# 13    1.0
# 14    NaN
# 15    3.0
# 16    3.0
# 17    NaN
# 18    4.0
# 19    3.0
# 20    NaN
# 21    4.0
# 22    2.0
# 23    NaN
# 24    3.0
# 25    NaN
# 26    1.0
# 27    1.0
# 28    NaN
# 29    2.0
# 30    1.0
# 31    NaN
# 32    4.0
# 33    3.0
# 34    NaN
# 35    4.0
# 36    4.0
# 37    NaN
# 38    2.0
# 39    NaN
# 40    1.0
# 41    1.0
# 42    NaN
# 43    3.0
# 44    3.0
# 45    NaN
# 46    4.0
# 47    2.0
# 48    NaN
# 49    2.0
# 50    2.0
# 51    NaN
# 52    1.0
# 53    NaN
# 54    1.0
# 55    1.0

# %%
provider_summary_df
# Out:
#    provider  week_32  week_33  week_34  week_35  total_clinic
# 0   Bedelle        6        6        6        6            24
# 1  Carrasco        6        0        4        6            16
# 2     Mador        0        4        0        0             4
# 3  Menachof        0        3        0        1             4
# 4    Miller        4        5        6        0            15
# 5    Powell        0        0        0        0             0
# 6      Shin        0        0        0        2             2
# 7   Sridhar        2        6        6        4            18
# 8      Tarr        0        0        0        0             0

# %%
call_summary_df
# Out:
#    provider  week_30  week_31  week_32  week_33  week_34  total_call
# 0   Bedelle        1        0        1        0        1           3
# 1  Carrasco        0        1        0        1        1           3
# 2     Mador        0        0        1        0        0           1
# 3  Menachof        0        0        1        0        1           2
# 4    Miller        0        1        0        1        0           2
# 5    Powell        0        1        1        1        1           4
# 6      Shin        0        0        0        2        0           2
# 7   Sridhar        0        2        1        0        0           3
# 8      Tarr        0        0        0        0        0           0

# %%
solution_status
# Out:
# {'Status': 'OPTIMAL',
#  'Minimum providers per session': 1,
#  'Objective value': 7600.0,
#  'Solve time': '0.017051 seconds',
#  'Branches': 1368,
#  'Conflicts': 12}
